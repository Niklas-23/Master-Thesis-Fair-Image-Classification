# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#pd.set_option('display.max_rows', None)

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# %reload_ext autoreload
from src.datasets.UTKFaceDataset import UTKFaceDataset

utk_dataset = UTKFaceDataset(target_name="Age", protected_feature_name="Gender")
train_dataset, valid_dataset, test_dataset = utk_dataset.get_datasets()

# %%
image_array = np.transpose(train_dataset[8][0], (1, 2, 0))
print(train_dataset[0][0].size())

plt.imshow(image_array)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 128, 128])

# %%
train_df = utk_dataset.get_train_dataframe()
print(train_df.head())
# Out:
#        Age  Gender  Race      Date_and_Time  \
# 9725    45       0     1  20170117204046200
# 1330    23       1     2  20170116164541818
# 17821    9       0     0  20170110225508509
# 17872   61       0     2  20170116183826361
# 21634   25       0     1  20170113132417184
#
#                                         File target_encoded  \
# 9725   45_0_1_20170117204046200.jpg.chip.jpg              2
# 1330   23_1_2_20170116164541818.jpg.chip.jpg              1
# 17821   9_0_0_20170110225508509.jpg.chip.jpg              0
# 17872  61_0_2_20170116183826361.jpg.chip.jpg              2
# 21634  25_0_1_20170113132417184.jpg.chip.jpg              1
#
#        protected_feature_encoded
# 9725                           0
# 1330                           1
# 17821                          0
# 17872                          0
# 21634                          0

# %%
# %reload_ext autoreload
from jupyter_notebooks.dataset_analysis.dataset_analysis_utils import plot_target_distribution

plot_target_distribution(train_df, "Gender", title="UTK Face Distribution of Feature Gender", save_fig_path="utk_face_gender_distribution")

# %%
plot_target_distribution(train_df, "target_encoded")

# %%
# %reload_ext autoreload
from jupyter_notebooks.dataset_analysis.dataset_analysis_utils import plot_protected_feature_distribution

plot_protected_feature_distribution(train_df, "target_encoded", "Gender")

# %%
valid_dataframe = utk_dataset.get_valid_dataframe()
print(len(train_df))
print(len(valid_dataframe))
plot_target_distribution(train_df, "target_encoded")
# Out:
# 16592
# 2844

# %%
plot_protected_feature_distribution(valid_dataframe, "target_encoded", "Gender")
