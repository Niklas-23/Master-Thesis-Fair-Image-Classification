# %%
import os

from src.datasets.CelebA_dataset import CelebADataset
import torch
import torchvision.transforms as transforms
from tqdm import tqdm
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# %reload_ext autoreload
from src.datasets.FairFaceDataset import FairFaceDataset

fair_face_dataset = FairFaceDataset(target_name="gender")
train_dataset, valid_dataset, test_dataset = fair_face_dataset.get_datasets()

#print(train_dataset[0])
# Out:
# ['Female' 'Male']
# [0, 1]
# ['Black' 'East Asian' 'Indian' 'Latino_Hispanic' 'Middle Eastern'
#  'Southeast Asian' 'White']
# [0, 6, 2]
# ['Female' 'Male']
# [0, 1]
# ['Black' 'East Asian' 'Indian' 'Latino_Hispanic' 'Middle Eastern'
#  'Southeast Asian' 'White']
# [0, 6, 2]
# ['Female' 'Male']
# [0, 1]
# ['Black' 'East Asian' 'Indian' 'Latino_Hispanic' 'Middle Eastern'
#  'Southeast Asian' 'White']
# [0, 6, 2]

# %%
print(len(train_dataset))
print(len(valid_dataset))
print(len(test_dataset))
# Out:
# 78070
# 8674
# 10954

# %%
print(train_dataset[0][0].size())
# Out:
# torch.Size([3, 128, 128])

# %%
image_array = np.transpose(train_dataset[2][0], (1, 2, 0))
print(train_dataset[0][0].size())

plt.imshow(image_array)
plt.axis('off') 
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 128, 128])

# %%
train_df = fair_face_dataset.get_train_dataframe()

# %%
train_df.loc[1, "gender"]
# Out:
# 'Female'

# %%
# %reload_ext autoreload
from jupyter_notebooks.dataset_analysis.dataset_analysis_utils import plot_target_distribution

plot_target_distribution(train_df, "gender")

# %%
plot_target_distribution(train_df, "race")

# %%
plot_target_distribution(train_df, "age")

# %%
# %reload_ext autoreload
from jupyter_notebooks.dataset_analysis.dataset_analysis_utils import plot_protected_feature_distribution

plot_protected_feature_distribution(train_df, "age", "race")
